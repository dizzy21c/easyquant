# %%
import pandas as pd
import numpy as np
import QUANTAXIS as QA
from QUANTAXIS.QAARP import QA_Risk, QA_User
from QUANTAXIS.QAEngine.QAThreadEngine import QA_Thread
from QUANTAXIS.QAUtil.QAParameter import MARKET_TYPE, RUNNING_ENVIRONMENT, ORDER_DIRECTION
from QAPUBSUB.consumer import subscriber_topic,  subscriber_routing
from QAPUBSUB.producer import publisher_routing
from QAStrategy.qactabase import QAStrategyCTABase
from QIFIAccount import QIFI_Account, ORDER_DIRECTION
from easyquant import EasyMq
from easyquant import MongoIo
import talib as tdx

# %%
stocklist_all=['600718']

# %%
data = QA.QA_fetch_stock_day_adv(stocklist_all,'2018-01-01','2020-11-30').data

# %%
ch= data.close[-1] * 1.1
cl= data.close[-1] * 0.9

# %%
data.close[-1]

# %%
df2=pd.concat([QA.MA(data.close, x) for x in (5,10,20,30,60,90,120,250) ], axis = 1).dropna()[-1:]
df2.columns = [u'm5',u'm10',u'm20',u'm30',u'm60',u'm90',u'm120', u'm250']

# %%
df_h = df2.apply(lambda x:x.max() <= ch,  axis = 1 )
df_l = df2.apply(lambda x:x.min() >= cl,  axis = 1 )

# %%
df2['dfh'] = df_h

# %%
df2['dfl'] = df_l

# %%
df2

# %%
aa = df2.iloc[-1:]

# %%
ma = df2.iloc[-1:].apply(lambda x:x.max() < 12,  axis = 1 )

# %%
mb = df2.iloc[-1:].apply(lambda x:x.min() > 12.5,  axis = 1 )

# %%
aa['ma'] = ma

# %%
aa['mb'] = mb

# %%
aa

# %%
cc=aa.append(bb).apply(lambda x : x == True)

# %%
cc.apply(lambda x : x)

# %%
exp1= lambda x:x+1 if  x>1 else x-1 if x < -4 else 0

# %%
exp1(-5)

# %%
aa=df2.iloc[-2:-1] #.apply(lambda x: True if x>11 and x < 12 else False, axis=1)

# %%
aa

# %%
type(aa)

# %%
pd.DataFrame(aa)

# %%
df2.m5.apply(lambda x: True if x>20 else False)

# %%
df2.apply(lambda x: True if x>0 else False, axis=1)

# %%
user = QA_User(username="admin", password='admin')

# %%
port = user.new_portfolio('test-portfolio')

# %%
port

# %%
code="000001"

# %%
code

# %%
code=code[0:2]

# %%
c

# %%
acc = QIFI_Account("admin", "admin")
acc.initial()

# %%
print(acc.message)

# %%
acc.log(acc.message)

# %%
codelist = ['600756']
stock_names = QA.QA_fetch_stock_name(codelist)
stock_names

# %%
codename = [stock_names.at[code] for code in codelist]

# %%
type(stock_names)

# %%
stock_names.index

# %%
[stock_names.at[code] for code in codelist]

# %%
from datetime import datetime, date
import time

# %%
mongo=MongoIo()

# %%
a=m.get_index_day('515050')

# %%
a.columns

# %%
d15m= m.get_index_min(code='515050')

# %%
d15m.tail()

# %%
code='515050'
data_min = mongo.get_index_min(code=code,type='5min')

# %%
date.today()

# %%
data_min.index[-1].timestamp()

# %%
time.time()

# %%
(time.time() - data_min.index[-1].timestamp()) / 60

# %%
pd.Timestamp(datetime.now()) - data_min.index[-1]

# %%
abc

# %%
datetime.combine(date.today(), datetime.now.time())

# %%
datatime.now()

# %%
datetime.now()

# %%
from easyquant import QATdx as qatdx

# %%
start=data_min.index[-1].strftime('%Y-%m-%d %H:%M:01')

# %%
start1.

# %%
start=start1.strftime('%Y-%m-%d %H:%M:01')

# %%
start

# %%
delta_min=5
add_df=qatdx.QA_fetch_get_index_min(code,start=start,end='2030-12-31', frequence='%dmin' % delta_min)

# %%
add_df.head()

# %%
abc=data_min.append(add_df)

# %%
data_min.tail()
# Out:
#                          amount  close    code       date   high    low  \
# datetime
# 2020-06-22 14:40:00  10678272.0  1.237  515050 2020-06-22  1.237  1.236
# 2020-06-22 14:45:00  20171456.0  1.239  515050 2020-06-22  1.240  1.236
# 2020-06-22 14:50:00  11727168.0  1.239  515050 2020-06-22  1.240  1.238
# 2020-06-22 14:55:00  18282176.0  1.240  515050 2020-06-22  1.241  1.239
# 2020-06-22 15:00:00  14139392.0  1.240  515050 2020-06-22  1.240  1.239
#
#                       open    time_stamp  type         vol
# datetime
# 2020-06-22 14:40:00  1.236  1.592808e+09  5min   8636300.0
# 2020-06-22 14:45:00  1.237  1.592808e+09  5min  16288900.0
# 2020-06-22 14:50:00  1.239  1.592809e+09  5min   9460400.0
# 2020-06-22 14:55:00  1.240  1.592809e+09  5min  14746500.0
# 2020-06-22 15:00:00  1.239  1.592809e+09  5min  11406400.0

# %%
add_df.drop(['date_stamp','datetime'],axis=1,inplace=True)

# %%
add_df.head()

# %%
data_min.append(add_df, sort=True)

# %%
qatdx.QA_fetch_get_stock_min

# %%
import json

# %%
data_min.T.to_json()
# Out:
# '{"1577957700000":{"amount":37820376.0,"close":0.998,"code":"515050","date":1577923200000,"high":1.004,"low":0.998,"open":1.004,"time_stamp":1577928900.0,"type":"5min","vol":37747000.0},"1577958000000":{"amount":21451352.0,"close":1.003,"code":"515050","date":1577923200000,"high":1.004,"low":0.998,"open":0.998,"time_stamp":1577929200.0,"type":"5min","vol":21405000.0},"1577958300000":{"amount":19140824.0,"close":1.003,"code":"515050","date":1577923200000,"high":1.004,"low":1.001,"open":1.004,"time_stamp":1577929500.0,"type":"5min","vol":19084500.0},"1577958600000":{"amount":29236328.0,"close":1.008,"code":"515050","date":1577923200000,"high":1.008,"low":1.001,"open":1.002,"time_stamp":1577929800.0,"type":"5min","vol":29075500.0},"1577958900000":{"amount":29860432.0,"close":1.012,"code":"515050","date":1577923200000,"high":1.013,"low":1.008,"open":1.008,"time_stamp":1577930100.0,"type":"5min","vol":29551800.0},"1577959200000":{"amount":22279136.0,"close":1.012,"code":"515050","date":1577923200000,"high":1.013,"low":1.01,"open":1.012,"time_stamp":1577930400.0,"type":"5min","vol":22020900.0},"1577959500000